# %% [markdown]
# # Sprint 1 - EDA
#
# **Objective:** Anomaly detection in Congress stock trades
#
# **Author:** Tiffany Chu
#
# **Date:** Mar 7, 2024

# %%
#importing preprocessing/visualization libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset
#
# The dataset consists of combined data from Senate stock transactions, stock news events, and S&P performance metrics. It covers the period from 2020 to 2023 and contains approximately 30,000 rows and 30 relevant columns.
#
# #### Data Dictionary
#
# **Here is some information about the columns in the US congress trades dataset:**
# - transaction_date: Date of the transaction.
# - owner: Owner of the asset (e.g., Senator, Spouse).
# - ticker: Ticker symbol of the asset.
# - asset_description: Description of the asset (e.g., company name, stock type).
# - asset_type: Type of asset (e.g., Stock, Bond, Real Estate).
# - type: Type of transaction (e.g., Sale (Full), Purchase, Exchange).
# - amount: Amount of the transaction in USD.
# - comment: Additional comments or remarks related to the transaction.
# - party: Political party affiliation of the Senator.
# - state: State represented by the Senator.
# - industry: Industry classification of the asset.
# - sector: Sector classification of the asset.
# - senator: Name of the Senator associated with the transaction.
# - ptr_link: URL link to the Public Financial Disclosure Report (PTR) on the Senate's website.
# - disclosure_date: Date when the transaction was disclosed.
#
# **Here is some information about the columns in the Stock news sentiment news dataset:**
# - Date: Date of the stock data.
# - Open: Opening price of the stock.
# - High: Highest price of the stock during the day.
# - Low: Lowest price of the stock during the day.
# - Close: Closing price of the stock.
# - Adj Close: Adjusted closing price of the stock (accounts for dividends and stock splits).
# - Volume: Volume of shares traded.
# - Symbol: Ticker symbol of the stock.
# - Security: Name of the company/security.
# - GICS Sector: Sector classification of the company based on the Global Industry Classification Standard (GICS).
# - GICS Sub-Industry: Sub-industry classification of the company based on the GICS.
# - News - All News Volume: Total volume of news articles related to the company.
# - News - Volume: Volume of news articles related to the company on the specific - date.
# - News - Positive Sentiment: Number of news articles with positive sentiment regarding the company.
# - News - Negative Sentiment: Number of news articles with negative sentiment regarding the company.
# - News - New Products: Indicator for news articles related to new products.
# - News - Layoffs: Indicator for news articles related to layoffs.
# - News - Analyst Comments: Indicator for news articles related to analyst comments.
# - News - Stocks: Indicator for news articles related to stocks.
# - News - Dividends: Indicator for news articles related to dividends.
# - News - Corporate Earnings: Indicator for news articles related to corporate earnings.
# - News - Mergers & Acquisitions: Indicator for news articles related to mergers and acquisitions.
# - News - Store Openings: Indicator for news articles related to store openings.
# - News - Product Recalls: Indicator for news articles related to product recalls.
# - News - Adverse Events: Indicator for news articles related to adverse events.
# - News - Personnel Changes: Indicator for news articles related to personnel changes.
# - News - Stock Rumors: Indicator for news articles related to stock rumors.

# %% [markdown]
# ## Table of Contents
#
# 1. Wrangle, process & clean the data
#     - preprocess and combine house.csv and senate.csv
#     - preprocess stock news dataset
# 2. EDA - Exploratory Data Analysis
#     - summary statistics
#     - plots

# %% [markdown]
# ## Wrangle, process & clean the data
# ### Combining senate and house datasets
# - to get all congress stock news in one dataset

# %%
raw_data = pd.read_csv(r"C:\Users\Tiffany\desktop\1sprint\house.csv")
raw_data2 = pd.read_csv(r"C:\Users\Tiffany\desktop\1sprint\senate.csv")

raw_data.head() #look at dataset
# Out:
#    disclosure_year disclosure_date transaction_date  owner ticker  \
# 0             2021      10/04/2021       2021-09-27  joint     BP
# 1             2021      10/04/2021       2021-09-13  joint    XOM
# 2             2021      10/04/2021       2021-09-10  joint   ILPT
# 3             2021      10/04/2021       2021-09-28  joint     PM
# 4             2021      10/04/2021       2021-09-17   self    BLK
#
#                                    asset_description          type  \
# 0                                             BP plc      purchase
# 1                            Exxon Mobil Corporation      purchase
# 2  Industrial Logistics Properties Trust - Common...      purchase
# 3                   Phillip Morris International Inc      purchase
# 4                                      BlackRock Inc  sale_partial
#
#               amount     representative district state  \
# 0   $1,001 - $15,000      Virginia Foxx     NC05    NC
# 1   $1,001 - $15,000      Virginia Foxx     NC05    NC
# 2  $15,001 - $50,000      Virginia Foxx     NC05    NC
# 3  $15,001 - $50,000      Virginia Foxx     NC05    NC
# 4   $1,001 - $15,000  Alan S. Lowenthal     CA47    CA
#
#                                             ptr_link  cap_gains_over_200_usd  \
# 0  https://disclosures-clerk.house.gov/public_dis...                   False
# 1  https://disclosures-clerk.house.gov/public_dis...                   False
# 2  https://disclosures-clerk.house.gov/public_dis...                   False
# 3  https://disclosures-clerk.house.gov/public_dis...                   False
# 4  https://disclosures-clerk.house.gov/public_dis...                   False
#
#                              industry                 sector       party
# 0            Integrated oil Companies                 Energy  Republican
# 1            Integrated oil Companies                 Energy  Republican
# 2       Real Estate Investment Trusts            Real Estate  Republican
# 3               Farming/Seeds/Milling  Consumer Non-Durables  Republican
# 4  Investment Bankers/Brokers/Service                Finance    Democrat

# %% [markdown]
# #### Combining Senate and House of Commons dataset
#
# Steps:
# - First loading the data
# - then changing column names from 'representative' or 'senator' to 'name' so they can be in the same column, since both are in the category of Congress
# - next keeping only relevant columns that both have in common
# - then reordering the columns so that both datasets have the same column order
# - lastly, merging on the specified columns

# %%
raw_data = pd.read_csv(r"C:\Users\Tiffany\desktop\1sprint\house.csv")
raw_data2 = pd.read_csv(r"C:\Users\Tiffany\desktop\1sprint\senate.csv")

#change column names from 'representative' or 'senator' to 'name' so they can be in the same column. Both in the category of Congress
raw_data2.rename(columns={'senator': 'name'}, inplace=True)
raw_data.rename(columns={'representative': 'name'}, inplace=True)

raw_data = raw_data[['transaction_date', 'owner', 'ticker', 'asset_description', 'type', 'amount', 'party', 'state', 'industry', 'sector', 'ptr_link', 'disclosure_date', 'name']]
raw_data2 = raw_data[['transaction_date', 'owner', 'ticker', 'asset_description', 'type', 'amount', 'party', 'state', 'industry', 'sector', 'ptr_link', 'disclosure_date', 'name']]

raw_data2 = raw_data2.reindex(columns=raw_data.columns)

# %%
raw_data = pd.merge(raw_data, raw_data2, on=['transaction_date', 'owner', 'ticker', 'asset_description', 'type', 'amount', 'party', 'state', 'industry', 'sector', 'ptr_link', 'disclosure_date', 'name'], how='inner')
raw_data.head()
# Out:
#   transaction_date  owner ticker  \
# 0       2021-09-27  joint     BP
# 1       2021-09-13  joint    XOM
# 2       2021-09-10  joint   ILPT
# 3       2021-09-28  joint     PM
# 4       2021-09-17   self    BLK
#
#                                    asset_description          type  \
# 0                                             BP plc      purchase
# 1                            Exxon Mobil Corporation      purchase
# 2  Industrial Logistics Properties Trust - Common...      purchase
# 3                   Phillip Morris International Inc      purchase
# 4                                      BlackRock Inc  sale_partial
#
#               amount       party state                            industry  \
# 0   $1,001 - $15,000  Republican    NC            Integrated oil Companies
# 1   $1,001 - $15,000  Republican    NC            Integrated oil Companies
# 2  $15,001 - $50,000  Republican    NC       Real Estate Investment Trusts
# 3  $15,001 - $50,000  Republican    NC               Farming/Seeds/Milling
# 4   $1,001 - $15,000    Democrat    CA  Investment Bankers/Brokers/Service
#
#                   sector                                           ptr_link  \
# 0                 Energy  https://disclosures-clerk.house.gov/public_dis...
# 1                 Energy  https://disclosures-clerk.house.gov/public_dis...
# 2            Real Estate  https://disclosures-clerk.house.gov/public_dis...
# 3  Consumer Non-Durables  https://disclosures-clerk.house.gov/public_dis...
# 4                Finance  https://disclosures-clerk.house.gov/public_dis...
#
#   disclosure_date               name
# 0      10/04/2021      Virginia Foxx
# 1      10/04/2021      Virginia Foxx
# 2      10/04/2021      Virginia Foxx
# 3      10/04/2021      Virginia Foxx
# 4      10/04/2021  Alan S. Lowenthal

# %% [markdown]
# ##### changing columns to their right format

# %%
#change date disclosure and transaction column to yyyy-mm-dd
raw_data['disclosure_date'] = pd.to_datetime(raw_data['disclosure_date'], errors='coerce')
raw_data['transaction_date'] = pd.to_datetime(raw_data['transaction_date'], errors='coerce')

# %%
raw_data.shape
# Out:
# (18774, 13)

# %%
raw_data.info() #checking datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18774 entries, 0 to 18773
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   transaction_date   18762 non-null  datetime64[ns]
#  1   owner              11612 non-null  object
#  2   ticker             18774 non-null  object
#  3   asset_description  18770 non-null  object
#  4   type               18774 non-null  object
#  5   amount             18774 non-null  object
#  6   party              18675 non-null  object
#  7   state              18774 non-null  object
#  8   industry           13815 non-null  object
#  9   sector             13815 non-null  object
#  10  ptr_link           18774 non-null  object
#  11  disclosure_date    18774 non-null  datetime64[ns]
#  12  name               18774 non-null  object
# dtypes: datetime64[ns](2), object(11)
# memory usage: 1.9+ MB

# %%
(raw_data.isna().mean() * 100).round(2) #checking percentages of columns that contain nulls
# Out:
# transaction_date      0.06
# owner                38.15
# ticker                0.00
# asset_description     0.02
# type                  0.00
# amount                0.00
# party                 0.53
# state                 0.00
# industry             26.41
# sector               26.41
# ptr_link              0.00
# disclosure_date       0.00
# name                  0.00
# dtype: float64

# %%
raw_data.isna().sum() # checking total sum of nulls in that column
# Out:
# transaction_date       12
# owner                7162
# ticker                  0
# asset_description       4
# type                    0
# amount                  0
# party                  99
# state                   0
# industry             4959
# sector               4959
# ptr_link                0
# disclosure_date         0
# name                    0
# dtype: int64

# %% [markdown]
# ##### Summary of Missing Values
# Having nulls in owner, industry, and sector is alright, as it is not required for this to be included, oftentimes if it is empty, that insinuates it is owned by oneself. However, the missing transaction date, asset description, and party is unusual and there are unclear reasons for these missing values.
#
# I now investigate and fill in or delete rows with missing values

# %%
raw_data['owner'].value_counts() # to see category names in owner column
# Out:
# owner
# joint        5867
# self         3854
# --           1343
# dependent     548
# Name: count, dtype: int64

# %%
nullrows = raw_data[raw_data[['industry', 'transaction_date']].isna().any(axis=1)]
print(nullrows)
# Out:
#       transaction_date  owner ticker  \
# 6           2021-11-30    NaN  KPLTW
# 15          2021-10-07  joint   DUKH
# 23          2022-09-08    NaN     --
# 24          2022-09-08    NaN     --
# 25          2022-09-14    NaN     --
# ...                ...    ...    ...
# 18721       2020-03-23  joint    UTX
# 18730       2020-05-08  joint    CNI
# 18734       2020-05-07  joint   CENT
# 18741       2020-05-12  joint   GRUB
# 18749       2020-05-11  joint  NSRGY
#
#                                        asset_description          type  \
# 6                        Katapult Holdings Inc - Warrant      purchase
# 15     Duke Energy Corporation 5.125% Junior Subordin...     sale_full
# 23                                   Harris County TX 5%     sale_full
# 24                            Main Mun Bd BK 5% 09/01/27     sale_full
# 25                               New York St 5% 06/15/27     sale_full
# ...                                                  ...           ...
# 18721                    United Technologies Corporation      purchase
# 18730                  Canadian National Railway Company  sale_partial
# 18734                       Central Garden & Pet Company  sale_partial
# 18741                                       GrubHub Inc.      purchase
# 18749  Nestle SA Sponsored ADR Representing Registere...  sale_partial
#
#                    amount       party state industry sector  \
# 6        $1,001 - $15,000  Republican    GA      NaN    NaN
# 15     $50,001 - $100,000  Republican    NC      NaN    NaN
# 23      $15,001 - $50,000  Republican    NY      NaN    NaN
# 24      $15,001 - $50,000  Republican    NY      NaN    NaN
# 25      $15,001 - $50,000  Republican    NY      NaN    NaN
# ...                   ...         ...   ...      ...    ...
# 18721    $1,001 - $15,000  Republican    WV      NaN    NaN
# 18730    $1,001 - $15,000    Democrat    NJ      NaN    NaN
# 18734    $1,001 - $15,000    Democrat    NJ      NaN    NaN
# 18741    $1,001 - $15,000    Democrat    NJ      NaN    NaN
# 18749    $1,001 - $15,000    Democrat    NJ      NaN    NaN
#
#                                                 ptr_link disclosure_date  \
# 6      https://disclosures-clerk.house.gov/public_dis...      2021-12-01
# 15     https://disclosures-clerk.house.gov/public_dis...      2021-11-02
# 23     https://disclosures-clerk.house.gov/public_dis...      2022-10-18
# 24     https://disclosures-clerk.house.gov/public_dis...      2022-10-18
# 25     https://disclosures-clerk.house.gov/public_dis...      2022-10-18
# ...                                                  ...             ...
# 18721  https://disclosures-clerk.house.gov/public_dis...      2020-04-15
# 18730  https://disclosures-clerk.house.gov/public_dis...      2020-06-10
# 18734  https://disclosures-clerk.house.gov/public_dis...      2020-06-10
# 18741  https://disclosures-clerk.house.gov/public_dis...      2020-06-10
# 18749  https://disclosures-clerk.house.gov/public_dis...      2020-06-10
#
#                     name
# 6           Austin Scott
# 15         Virginia Foxx
# 23          Chris Jacobs
# 24          Chris Jacobs
# 25          Chris Jacobs
# ...                  ...
# 18721  David B. McKinley
# 18730    Josh Gottheimer
# 18734    Josh Gottheimer
# 18741    Josh Gottheimer
# 18749    Josh Gottheimer
#
# [4967 rows x 13 columns]

# %% [markdown]
# **Since the transaction date must be at most 45 days before the disclosure date, we will assume this and input the 12 missing transaction dates with this**

# %%
#using the disclosure date column but with the date 45 days prior
raw_data['transaction_date'].fillna(raw_data['disclosure_date'] - pd.Timedelta(days=45), inplace=True)
print(raw_data['transaction_date'].isna().sum()) #check again, should be 0 after
# Out:
# 0

# %%
#replace the null values in the 'owner' column with the string 'self' 
print(raw_data['owner'].isna().sum())
raw_data['owner'].fillna('self', inplace=True)
print(raw_data['owner'].isna().sum()) #check again, should be 0 after
# Out:
# 7162
# 0

# %% [markdown]
# **Identifying party nulls and manually inputting**
# - checked that the list of names where there is a missing party, has missing parties in ALL rows with that name, so the only choice is to manually input. Turns out theyre all democrats

# %%
rows_with_nulls = raw_data[raw_data['party'].isna()]
namelist = rows_with_nulls['name'].tolist()
pd.Series(namelist).value_counts()
# Out:
# Jared Moskowitz        35
# Shri Thanedar          30
# Jonathan Jackson       10
# Max Miller              7
# Morgan McGarvey         6
# Eric Burlison           5
# Ada Norah Henriquez     4
# Jeff Jackson            2
# Name: count, dtype: int64

# %%
raw_data['party'].fillna('Democrat', inplace=True) #replacing NaN with democrat
print(raw_data['party'].isna().sum()) #check again, should be 0 after
# Out:
# 0

# %%
#replace the null values in the 'industry' column with the string 'na' 
print(raw_data['industry'].isna().sum())
raw_data['industry'].fillna('na', inplace=True)
print(raw_data['industry'].isna().sum()) #check again, should be 0 after
# Out:
# 4959
# 0

# %%
#since the last 2 columns with missing values (industry and sector) are categories, change them to 'na'
raw_data.fillna('unknown', inplace=True)
print(raw_data.isna().sum()) #check again, should be 0 after
# Out:
# transaction_date     0
# owner                0
# ticker               0
# asset_description    0
# type                 0
# amount               0
# party                0
# state                0
# industry             0
# sector               0
# ptr_link             0
# disclosure_date      0
# name                 0
# dtype: int64

# %%
raw_data.describe().T
# Out:
#                   count                          mean        min        25%  \
# transaction_date  18774 2021-02-21 16:02:18.063279104 2012-06-19 2020-05-14
# disclosure_date   18774 2021-04-19 17:27:12.598274048 2020-01-02 2020-07-08
#
#                         50%        75%        max
# transaction_date 2021-01-15 2021-10-22 2023-12-22
# disclosure_date  2021-03-03 2021-12-03 2023-05-14

# %% [markdown]
# ### EDA

# %%
#bar chart showing the count of rows for each party after grouping
party_counts = raw_data.groupby('party').size()
party_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Rows by Party')
plt.xlabel('Party')
plt.ylabel('Count');

raw_data.groupby('party').size()
# Out:
# party
# Democrat       11474
# Jackson           14
# Libertarian        5
# Republican      7281
# dtype: int64

# %%
raw_data['year'] = raw_data['transaction_date'].dt.year

grouped_data1 = raw_data.groupby(['year', 'party']).size().unstack()
grouped_data1.plot(kind='bar', stacked=True, colormap='Paired')
plt.title('Number of Rows by Year and Party')
plt.xlabel('Year')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#pie chart showing the distribution of sectors in congress trades

sectorcounts = raw_data['sector'].value_counts()
percentages = sectorcounts / len(raw_data) * 100
sectorcounts1 = sectorcounts[percentages >= 1]
plt.figure(figsize=(10,10))  
plt.pie(sectorcounts1, labels=sectorcounts1.index, autopct='%1.f%%');

raw_data['sector'].value_counts()
# Out:
# sector
# unknown                   4959
# Technology                2913
# Health Care               1807
# Finance                   1527
# Consumer Services         1416
# Energy                     922
# Public Utilities           905
# Consumer Discretionary     839
# Capital Goods              739
# Industrials                590
# Consumer Non-Durables      501
# Miscellaneous              487
# Basic Industries           340
# Real Estate                250
# Consumer Durables          198
# Transportation             153
# Utilities                  110
# Consumer Staples            54
# Telecommunications          35
# Basic Materials             29
# Name: count, dtype: int64

# %%
amt = raw_data['amount'].value_counts()

amt.plot(kind='bar', stacked=True, colormap='Paired')
plt.title('Amount Invested')
plt.xlabel('Amount Range')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
raw_data['amount'].value_counts()
# Out:
# amount
# $1,001 - $15,000            13064
# $15,001 - $50,000            3010
# $50,001 - $100,000            951
# $100,001 - $250,000           717
# $1,001 -                      391
# $250,001 - $500,000           315
# $500,001 - $1,000,000         199
# $1,000,001 - $5,000,000        77
# $1,000,000 +                   32
# $5,000,001 - $25,000,000        9
# $1,000 - $15,000                4
# $15,000 - $50,000               3
# $50,000,000 +                   1
# $1,000,000 - $5,000,000         1
# Name: count, dtype: int64

# %%
#feature engineering - 
#adding new column for upper bound to replicate amount but in a numerical format
raw_data['upper_bound'] = raw_data['amount'].str.split(' - ').str[-1]
#using regex 
raw_data['upper_bound'] = raw_data['upper_bound'].str.replace('[^\d]', '', regex=True).astype(float)
# values like $1,000,000 +  and $50,000,000 +   become NaNs, so change to their lower bound
raw_data['upper_bound'] = raw_data['upper_bound'].fillna(raw_data['amount'].str.split(' - ').str[0])
raw_data['upper_bound'].value_counts() #double checking
# Out:
# upper_bound
# 15000.0       13068
# 50000.0        3013
# 100000.0        951
# 250000.0        717
# 1001.0          391
# 500000.0        315
# 1000000.0       231
# 5000000.0        78
# 25000000.0        9
# 50000000.0        1
# Name: count, dtype: int64

# %%
#filter data to include only amounts over $5,000,000
amt5mil = raw_data[raw_data['upper_bound'] > 500000]

#the representatives with amounts over $5,000,000
print(amt5mil[['upper_bound', 'name']].value_counts())

#amt5mil.groupby('name')['upper_bound'].sum().sort_values(ascending=False)
# Out:
# upper_bound  name
# 1000000.0    Suzan K. DelBene          45
#              Scott H. Peters           41
#              Nancy Pelosi              38
# 5000000.0    Josh Gottheimer           33
# 1000000.0    Mark E. Green             24
#              Josh Gottheimer           22
# 5000000.0    Nancy Pelosi              19
# 1000000.0    Doris O. Matsui           13
#              Michael T. McCaul          9
# 25000000.0   Suzan K. DelBene           6
# 5000000.0    Kevin Hern                 5
#              Suzan K. DelBene           5
# 1000000.0    Kathy Manning              5
#              Kevin Hern                 5
#              Gilbert Cisneros           3
# 5000000.0    Scott Franklin             3
#              Mark E. Green              3
# 1000000.0    Van Taylor                 3
#              Trey Hollingsworth         3
# 5000000.0    Kim Schrier                2
# 1000000.0    Brad Sherman               2
#              Kim Schrier                2
#              Bradley S. Schneider       2
#              Ro Khanna                  2
# 25000000.0   Josh Gottheimer            2
# 5000000.0    Donald S. Beyer, Jr.       2
# 1000000.0    Greg Gianforte             2
# 5000000.0    Van Taylor                 2
#              Sara Jacobs                1
# 25000000.0   Michael Waltz              1
# 1000000.0    Ashley Hinson Arenholz     1
# 5000000.0    Dan Daniel Bishop          1
#              Ann Wagner                 1
#              Adrian Smith               1
# 1000000.0    Victoria Spartz            1
#              Tom Cole                   1
#              Michael Waltz              1
#              Jamie Raskin               1
#              Harley E. Rouda            1
#              Fred Upton                 1
#              Donald S. Beyer, Jr.       1
#              Chellie Pingree            1
#              Carolyn B. Maloney         1
# 50000000.0   Kevin Hern                 1
# Name: count, dtype: int64

# %%
raw_data.groupby('name')['upper_bound'].sum().sort_values(ascending=False).head(20)
# Out:
# name
# Josh Gottheimer         300345000.0
# Suzan K. DelBene        243325000.0
# Nancy Pelosi            146432002.0
# Kevin Hern              122795000.0
# Mark E. Green           122430000.0
# Scott H. Peters          63240000.0
# Michael T. McCaul        48290000.0
# Greg Gianforte           38400000.0
# Donald S. Beyer, Jr.     29725000.0
# Michael Waltz            26100000.0
# K. Michael Conaway       21810000.0
# Gilbert Cisneros         19675000.0
# Virginia Foxx            19360000.0
# Scott Franklin           19300000.0
# Kim Schrier              18015000.0
# Van Taylor               16210000.0
# Kathy Manning            14990000.0
# Doris O. Matsui          14865000.0
# James R. Langevin        12840000.0
# Alan S. Lowenthal        12162362.0
# Name: upper_bound, dtype: float64

# %%
swag = raw_data.groupby(['upper_bound', 'party']).size().unstack()

#amt = raw_data['amount'].value_counts()
swag.plot(kind='bar', stacked=True, colormap='Paired')
plt.title('Amount Invested')
plt.xlabel('Amount Range')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Adding S&P Stock Price based on transaction date
# - (S&P) is a leading index provider and data source of independent credit ratings. The name comes from the merger of two financial data publications. For more than half a century, the S&P 500 has been an indicator for the performance of the stock market overall. Because it represents the largest publicly traded corporations in the US, its performance is seen as a snapshot of the state of US business, and by extension, the US economy. Here I use the S&P close price (adjusted), which is the final price at which the index traded on a particular trading day, after accounting for any corporate actions such as stock splits, dividends, or other adjustments that may affect the price -- a benchmark for evaluating the performance of top individual stocks
#
# - Also adding the S&P volume, unlike a market index which suggests the market performance, the S&P 500 volume signifies the total number of shares of all securities traded on the S&P 500 index. It reflects the level of market activity -- higher volume indicates a higher number of traders that are interested in buying or selling, lower indicates a negative perception, it means that the price of a stock can decline shortly, and it can show a bearish pattern/ going down.

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\tiffany\anaconda3\lib\site-packages (0.2.37)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\tiffany\anaconda3\lib\site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\tiffany\anaconda3\lib\site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in c:\users\tiffany\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\tiffany\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\tiffany\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\tiffany\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in c:\users\tiffany\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\tiffany\anaconda3\lib\site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\tiffany\anaconda3\lib\site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\tiffany\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\tiffany\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\tiffany\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in c:\users\tiffany\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\tiffany\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tiffany\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\tiffany\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tiffany\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tiffany\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tiffany\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tiffany\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.2.2)

# %%
import yfinance as yf

# %%
sp = "^GSPC"  #ticker symbol for S&P 500
sp500_data = yf.download(sp, start="2017-01-01", end="2024-01-01")
data = raw_data[raw_data['transaction_date'].dt.year >= 2017]
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
sp500_data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-01-03  2251.570068  2263.879883  2245.129883  2257.830078  2257.830078
# 2017-01-04  2261.600098  2272.820068  2261.600098  2270.750000  2270.750000
# 2017-01-05  2268.179932  2271.500000  2260.449951  2269.000000  2269.000000
# 2017-01-06  2271.139893  2282.100098  2264.060059  2276.979980  2276.979980
# 2017-01-09  2273.590088  2275.489990  2268.899902  2268.899902  2268.899902
# ...                 ...          ...          ...          ...          ...
# 2023-12-22  4753.919922  4772.939941  4736.770020  4754.629883  4754.629883
# 2023-12-26  4758.859863  4784.720215  4758.450195  4774.750000  4774.750000
# 2023-12-27  4773.450195  4785.390137  4768.899902  4781.580078  4781.580078
# 2023-12-28  4786.439941  4793.299805  4780.979980  4783.350098  4783.350098
# 2023-12-29  4782.879883  4788.430176  4751.990234  4769.830078  4769.830078
#
#                 Volume
# Date
# 2017-01-03  3773010000
# 2017-01-04  3768890000
# 2017-01-05  3785080000
# 2017-01-06  3342080000
# 2017-01-09  3219730000
# ...                ...
# 2023-12-22  3046770000
# 2023-12-26  2513910000
# 2023-12-27  2748450000
# 2023-12-28  2698860000
# 2023-12-29  3126060000
#
# [1760 rows x 6 columns]

# %%
# add/merge the S&P 500 data with the original dataset on the transaction date
data = pd.merge(raw_data, sp500_data[['Adj Close', 'Volume']], left_on='transaction_date', right_index=True, how='left')

#rename S&P data as a new column in raw_data
data.rename(columns={'Adj Close': 'SP500_Close'}, inplace=True)

#since data has unorganized dates in non-sequential rows, reorder it by sorting the
#dataset based on the date column
data.sort_values(by='transaction_date', inplace=True)

data.head()
# Out:
#       transaction_date owner ticker  \
# 12594       2012-06-19  self  BLFSD
# 13574       2017-09-05  self    SUP
# 13555       2017-12-06  self    CAT
# 13554       2018-04-17  self     BA
# 13560       2018-04-30  self   CTRL
#
#                                        asset_description      type  \
# 12594                              BioLife Solutions Inc  purchase
# 13574  Superior Industries International Inc Common S...  purchase
# 13555                                    Caterpillar Inc  purchase
# 13554                                     Boeing Company  purchase
# 13560                               Control4 Corporation  purchase
#
#                   amount     party state                          industry  \
# 12594   $1,001 - $15,000  Democrat    NJ                                na
# 13574   $1,001 - $15,000  Democrat    NY                 Auto Parts:O.E.M.
# 13555   $1,001 - $15,000  Democrat    NY  Construction/Ag Equipment/Trucks
# 13554  $15,001 - $50,000  Democrat    NY                         Aerospace
# 13560   $1,001 - $15,000  Democrat    NY                                na
#
#                        sector  \
# 12594                 unknown
# 13574  Consumer Discretionary
# 13555           Capital Goods
# 13554           Capital Goods
# 13560                 unknown
#
#                                                 ptr_link disclosure_date  \
# 12594  https://disclosures-clerk.house.gov/public_dis...      2021-08-26
# 13574  https://disclosures-clerk.house.gov/public_dis...      2022-03-03
# 13555  https://disclosures-clerk.house.gov/public_dis...      2022-03-03
# 13554  https://disclosures-clerk.house.gov/public_dis...      2022-03-03
# 13560  https://disclosures-clerk.house.gov/public_dis...      2022-03-03
#
#                  name  year  upper_bound  SP500_Close        Volume
# 12594  Tom Malinowski  2012      15000.0          NaN           NaN
# 13574   Thomas Suozzi  2017      15000.0  2457.850098  3.502190e+09
# 13555   Thomas Suozzi  2017      15000.0  2629.270020  3.253080e+09
# 13554   Thomas Suozzi  2018      50000.0  2706.389893  3.286190e+09
# 13560   Thomas Suozzi  2018      15000.0  2648.050049  3.749510e+09

# %% [markdown]
# ### Baseline time series analyses

# %%
#since data has unorganized dates in non-sequential rows, reorder it by sorting the dataset based on the date column
data.sort_values(by='transaction_date', inplace=True)


# Plot Volume
plt.subplot(2, 1, 1)
plt.plot(data['transaction_date'], data['Volume'], color='red', linestyle='-')
plt.title('Volume')
plt.xlabel('Date')
plt.ylabel('Volume')

# Plot S&P 500 Close Price
plt.subplot(2, 1, 2)
plt.plot(data['transaction_date'], data['SP500_Close'], color='blue', linestyle='-')
plt.title('S&P 500 Close Price')
plt.xlabel('Date')
plt.ylabel('Close Price')

plt.tight_layout()

# %% [markdown]
# In the below blocks of code, I take an example senator and plot their investments into/out of the market over time, I also compare their investments the market.

# %%
#using the Congress member: Nancy Pelosi

nancy_pelosi_data = data[data['name'] == 'Nancy Pelosi']

nancy_pelosi_data = nancy_pelosi_data[['transaction_date', 'upper_bound', 'type']]

nancy_pelosi_data.sort_values(by='transaction_date', inplace=True)

#make a column of 0s for net
nancy_pelosi_data['net'] = 0

#iterate over each row to update the 'net' column
net_sum = 0
for index, row in nancy_pelosi_data.iterrows():
    if row['type'] == 'purchase':
        net_sum += row['upper_bound']
    else:
        net_sum -= row['upper_bound']
    nancy_pelosi_data.at[index, 'net'] = net_sum

#turn into dataframe
pd.DataFrame(nancy_pelosi_data)
# Out:
#      transaction_date  upper_bound          type       net
# 8236       2020-01-16     500000.0      purchase    500000
# 8234       2020-01-16     500000.0     sale_full         0
# 8235       2020-01-16     500000.0      purchase    500000
# 8233       2020-01-16     500000.0     sale_full         0
# 8232       2020-01-16    5000000.0      purchase   5000000
# ...               ...          ...           ...       ...
# 9057       2022-12-29     500000.0  sale_partial  35568999
# 9058       2022-12-30     500000.0  sale_partial  35068999
# 337        2023-01-20       1001.0     sale_full  35067998
# 7642       2023-03-09    1000000.0      purchase  36067998
# 7641       2023-03-17    1000000.0      purchase  37067998
#
# [100 rows x 4 columns]

# %%
#plotting her net investments
plt.figure(figsize=(10, 9))
plt.plot(nancy_pelosi_data['transaction_date'], nancy_pelosi_data['net'], color='blue', linestyle='-')
plt.title("Nancy Pelosi's Net Amount Over Time")
plt.xlabel('Transaction Date')
plt.ylabel('Net Amount')
plt.grid(True)
plt.xticks(rotation=45);

# %% [markdown]
# Demonstrating how unscaled data looks. Pelosi's investments dominate other features in the data.

# %%
# pelosi's investments vs Market index Price

plt.figure(figsize=(10, 6))

#Nancy Pelosi's net amount over time
plt.plot(nancy_pelosi_data['transaction_date'], nancy_pelosi_data['net'], color='blue', marker='o', linestyle='-', label="Nancy Pelosi's Net Amount")

#filter S&P 500 data for the specified date range
sp500_filtered = data[(data['transaction_date'] >= '2020-01-01') & (data['transaction_date'] <= '2023-05-31')]

#plot sp500 too
plt.plot(sp500_filtered['transaction_date'], sp500_filtered['SP500_Close'], color='red', linestyle='-', label="S&P 500 Index")

plt.title("Nancy Pelosi's Net Amount vs. S&P 500 Index Over Time")
plt.xlabel('Transaction Date')
plt.ylabel('Amount / S&P 500 Index')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# %%
#this is how the S&P Index close price actually looks when not in comparison
plt.plot(data['transaction_date'], data['SP500_Close'], color='red', linestyle='-', label="S&P 500 Index")

# %% [markdown]
# similarly, adding a column to the dataset that has the calculated net amount of each congress member over time (like what was done with Nancy Pelosi)

# %%
grouped_data = data.groupby('name')

result_df = pd.DataFrame()

#iterate over each group (aka congress member)
for name, group in grouped_data:
    group.sort_values(by='transaction_date', inplace=True)
    # fill net with 0s
    group['net'] = 0
    #initialize net_sum
    net_sum = 0
    
    #update the 'net' column same as nancy pelosi
    for index, row in group.iterrows():
        if row['type'] == 'purchase':
            net_sum += row['upper_bound']
        else:
            net_sum -= row['upper_bound']
        group.at[index, 'net'] = net_sum
    
    # Append the group (congress member) to the result DataFrame
    result_df = pd.concat([result_df, group], ignore_index=True)

# Display the resulting DataFrame
result_df.sort_values(by='transaction_date', inplace=True)

data = result_df

data.head()
# Out:
#       transaction_date owner ticker  \
# 17668       2012-06-19  self  BLFSD
# 17534       2017-09-05  self    SUP
# 17535       2017-12-06  self    CAT
# 17536       2018-04-17  self     BA
# 17537       2018-04-30  self   CTRL
#
#                                        asset_description      type  \
# 17668                              BioLife Solutions Inc  purchase
# 17534  Superior Industries International Inc Common S...  purchase
# 17535                                    Caterpillar Inc  purchase
# 17536                                     Boeing Company  purchase
# 17537                               Control4 Corporation  purchase
#
#                   amount     party state                          industry  \
# 17668   $1,001 - $15,000  Democrat    NJ                                na
# 17534   $1,001 - $15,000  Democrat    NY                 Auto Parts:O.E.M.
# 17535   $1,001 - $15,000  Democrat    NY  Construction/Ag Equipment/Trucks
# 17536  $15,001 - $50,000  Democrat    NY                         Aerospace
# 17537   $1,001 - $15,000  Democrat    NY                                na
#
#                        sector  \
# 17668                 unknown
# 17534  Consumer Discretionary
# 17535           Capital Goods
# 17536           Capital Goods
# 17537                 unknown
#
#                                                 ptr_link disclosure_date  \
# 17668  https://disclosures-clerk.house.gov/public_dis...      2021-08-26
# 17534  https://disclosures-clerk.house.gov/public_dis...      2022-03-03
# 17535  https://disclosures-clerk.house.gov/public_dis...      2022-03-03
# 17536  https://disclosures-clerk.house.gov/public_dis...      2022-03-03
# 17537  https://disclosures-clerk.house.gov/public_dis...      2022-03-03
#
#                  name  year  upper_bound  SP500_Close        Volume    net
# 17668  Tom Malinowski  2012      15000.0          NaN           NaN  15000
# 17534   Thomas Suozzi  2017      15000.0  2457.850098  3.502190e+09  15000
# 17535   Thomas Suozzi  2017      15000.0  2629.270020  3.253080e+09  30000
# 17536   Thomas Suozzi  2018      50000.0  2706.389893  3.286190e+09  80000
# 17537   Thomas Suozzi  2018      15000.0  2648.050049  3.749510e+09  95000

# %%
#extract the 10 congress members with the highest net
highest_net = data.sort_values(by='net', ascending=False)
top_net_names = highest_net['name'].unique()[:10]
top_net_values = highest_net[highest_net['name'].isin(top_net_names)].groupby('name')['net'].max().sort_values(ascending=False)

colors = {'Republican': 'red', 'Democrat': 'blue'}
party_colors = [colors[data[data['name'] == name]['party'].values[0]] for name in top_net_names]
plt.bar(top_net_names, top_net_values, color=party_colors)
plt.xlabel('Congress Member')
plt.ylabel('Net')
plt.title('Net Values of Top 10 Congress Members')
plt.xticks(rotation=45, ha='right')

for i in range(len(top_net_names)):
    plt.text(top_net_names[i], top_net_values[i], str(top_net_values[i]), ha='center', va='center', rotation=90)

# %%
result_df['transaction_unix_timestamp'] = result_df['transaction_date'].astype('int64') // 10**9
result_df['disclosure_unix_timestamp'] = result_df['disclosure_date'].astype('int64') // 10**9

# %%
col_drop = ['transaction_date', 'disclosure_date']
result_df = result_df.drop(columns=col_drop)
result_df.head()
# Out:
#       owner ticker                                  asset_description  \
# 17668  self  BLFSD                              BioLife Solutions Inc
# 17534  self    SUP  Superior Industries International Inc Common S...
# 17535  self    CAT                                    Caterpillar Inc
# 17536  self     BA                                     Boeing Company
# 17537  self   CTRL                               Control4 Corporation
#
#            type             amount     party state  \
# 17668  purchase   $1,001 - $15,000  Democrat    NJ
# 17534  purchase   $1,001 - $15,000  Democrat    NY
# 17535  purchase   $1,001 - $15,000  Democrat    NY
# 17536  purchase  $15,001 - $50,000  Democrat    NY
# 17537  purchase   $1,001 - $15,000  Democrat    NY
#
#                                industry                  sector  \
# 17668                                na                 unknown
# 17534                 Auto Parts:O.E.M.  Consumer Discretionary
# 17535  Construction/Ag Equipment/Trucks           Capital Goods
# 17536                         Aerospace           Capital Goods
# 17537                                na                 unknown
#
#                                                 ptr_link            name  \
# 17668  https://disclosures-clerk.house.gov/public_dis...  Tom Malinowski
# 17534  https://disclosures-clerk.house.gov/public_dis...   Thomas Suozzi
# 17535  https://disclosures-clerk.house.gov/public_dis...   Thomas Suozzi
# 17536  https://disclosures-clerk.house.gov/public_dis...   Thomas Suozzi
# 17537  https://disclosures-clerk.house.gov/public_dis...   Thomas Suozzi
#
#        year  upper_bound  SP500_Close        Volume    net  \
# 17668  2012      15000.0          NaN           NaN  15000
# 17534  2017      15000.0  2457.850098  3.502190e+09  15000
# 17535  2017      15000.0  2629.270020  3.253080e+09  30000
# 17536  2018      50000.0  2706.389893  3.286190e+09  80000
# 17537  2018      15000.0  2648.050049  3.749510e+09  95000
#
#        transaction_unix_timestamp  disclosure_unix_timestamp
# 17668                  1340064000                 1629936000
# 17534                  1504569600                 1646265600
# 17535                  1512518400                 1646265600
# 17536                  1523923200                 1646265600
# 17537                  1525046400                 1646265600

# %% [markdown]
# ## Scaling data
#
# Columns that need scaling are numerical features that are not binary or ordinal. In this dataset, the following columns:
#
# - upper_bound: Amount of the transaction in USD
# - SP500_close: The closing price of the market index
# - Volume: Volume of trades for the day.
#
# These columns contain numerical values that need to be scaled because it ensures that all features contribute equally to the analysis, and prevents features with larger scales from dominating the model. So, I use **Robust Scaling:**, It is suitable when dealing with datasets containing outliers, as it is less affected by them compared to Min-Max Scaling and Standardization, since its also ROBUST to outliers.

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

sp = sp500_filtered['SP500_Close'].values.reshape(-1, 1)
pelosi = nancy_pelosi_data['net'].values.reshape(-1, 1)

pelosi_scale = scaler.fit_transform(pelosi)
sp_scale = scaler.fit_transform(sp)

#plotting post-scaling
plt.plot(nancy_pelosi_data['transaction_date'], pelosi_scale, color='blue', marker='o', linestyle='-', label="Nancy Pelosi's Net Amount (scaled)")
filtered_dates = data['transaction_date'].iloc[:len(sp_scale)]
plt.plot(filtered_dates, sp_scale, color='red', linestyle='-', label="S&P 500 Index (Scaled)")
plt.title("Scaled Nancy Pelosi's Net Amount vs. Scaled S&P 500 Index Over Time")
plt.xlabel('Transaction Date')
plt.ylabel('Scaled Amount / Scaled S&P 500 Index')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()

# %%
sp1 = data['SP500_Close'].values.reshape(-1, 1)
sp_scale1 = scaler.fit_transform(sp1)

vol1 = data['Volume'].values.reshape(-1, 1)
vol_scale1 = scaler.fit_transform(vol1)

plt.plot(data['transaction_date'], sp_scale1, color='red', linestyle='-', label="S&P 500 closed")
#plt.plot(data['transaction_date'], upper_bound_scale, color='blue', linestyle='-', label="S&P 500 closed")
plt.plot(data['transaction_date'], vol_scale1, color='green', linestyle='-', label="S&P 500 volume")
plt.legend()

# %% [markdown]
# ## One Hot Encoding
# type, party, industry, sector, owner -- are all categorical columns that can be turned into dummy variables for each category item

# %%
from sklearn.preprocessing import StandardScaler
#scale numerical columns 
numerical_columns = ['year', 'upper_bound', 'SP500_Close', 'Volume', 'net', 'transaction_unix_timestamp', 'disclosure_unix_timestamp']

scaler = StandardScaler()
result_df[numerical_columns] = scaler.fit_transform(result_df[numerical_columns])

object_columns = ['owner', 'type', 'party', 'industry', 'sector', 'name']
data_dummies = pd.get_dummies(result_df, columns=object_columns)

col_drop = ['amount', 'state', 'ticker', 'asset_description', 'ptr_link', 'year']
data_dummies = data_dummies.drop(columns=col_drop)

# %%
#removing NaNs in columns, theres 2 rows
data_dummies = data_dummies.dropna().replace([np.inf, -np.inf], np.nan).dropna()

data_dummies.shape
# Out:
# (18667, 376)

# %%
booleans = data_dummies.select_dtypes(include=bool).columns
data_dummies[booleans] = data_dummies[booleans].astype(int)

# %%
data_dummies.head() #checking to see if scaling and one hot encoding worked as intended
# Out:
#        upper_bound  SP500_Close    Volume       net  \
# 17534    -0.100195    -1.956683 -1.020315  0.068212
# 17535    -0.100195    -1.673168 -1.208407  0.069868
# 17536    -0.052942    -1.545617 -1.183407  0.075389
# 17537    -0.100195    -1.642107 -0.833575  0.077045
# 17538    -0.100195    -1.602628 -0.836905  0.075389
#
#        transaction_unix_timestamp  disclosure_unix_timestamp  owner_--  \
# 17534                   -3.618599                    0.97133         0
# 17535                   -3.355567                    0.97133         0
# 17536                   -2.978174                    0.97133         0
# 17537                   -2.941006                    0.97133         0
# 17538                   -2.918134                    0.97133         0
#
#        owner_dependent  owner_joint  owner_self  ...  name_Van Taylor  \
# 17534                0            0           1  ...                0
# 17535                0            0           1  ...                0
# 17536                0            0           1  ...                0
# 17537                0            0           1  ...                0
# 17538                0            0           1  ...                0
#
#        name_Vern Buchanan  name_Vicente Gonzalez  name_Victoria Spartz  \
# 17534                   0                      0                     0
# 17535                   0                      0                     0
# 17536                   0                      0                     0
# 17537                   0                      0                     0
# 17538                   0                      0                     0
#
#        name_Virginia Foxx  name_W. Gregory Steube  name_William R. Keating  \
# 17534                   0                       0                        0
# 17535                   0                       0                        0
# 17536                   0                       0                        0
# 17537                   0                       0                        0
# 17538                   0                       0                        0
#
#        name_William R. Timmons  name_Wm. Lacy Clay  name_Zoe Lofgren
# 17534                        0                   0                 0
# 17535                        0                   0                 0
# 17536                        0                   0                 0
# 17537                        0                   0                 0
# 17538                        0                   0                 0
#
# [5 rows x 376 columns]

# %% [markdown]
# ## Modelling

# %% [markdown]
# ### Clustering
# - hoping to find two clusters - anomaly and non-anomaly
# - then running an autoencorder to get anomaly-labelled ones
# - finally comparing the two to see if the results are the same
# -
#
# - score is positive, which generally indicates that the clusters are well-separated
# - but relatively close to 0, suggesting some degree of overlap between clusters or some points being close to the decision boundary
# - Overall, a silhouette score of 0.2123 indicates a reasonable level of separation between clusters

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_samples, silhouette_score

agglomerative_clustering = AgglomerativeClustering(n_clusters=2) #2 clusters

cluster_labels = agglomerative_clustering.fit_predict(data_dummies)

silhouette_avg = silhouette_score(data_dummies, cluster_labels)

silhouette_avg
# Out:
# 0.1820026641426206

# %%
#threshold for silhouette score to identify anomalous points
threshold = 0

#the indices of anomalous points based on silhouette score
anomalous_indices = np.where(silhouette_samples(data_dummies, cluster_labels) < threshold)[0]

# %%
anomalous_df = data_dummies.iloc[anomalous_indices]
anomalous_df
#965 out of 18667 rows were marked as anomalous, that's 5% of rows
# Out:
#        upper_bound  SP500_Close    Volume       net  \
# 3596      6.629919    -1.077060 -1.225592  0.618643
# 11131     0.217072    -0.605676 -0.915333 -5.536022
# 14818     6.629919    -0.536029 -0.991329  0.618643
# 11132    -0.100195    -0.567817 -0.646782 -5.534365
# 11138    -0.100195    -0.431253 -1.082600 -5.524428
# ...            ...          ...       ...       ...
# 13927    -0.052942     1.359881  2.586011  0.052754
# 13872     0.554591     1.389701  0.100670  0.062691
# 16168    -0.052942     0.812481  1.486809  0.074837
# 16169    -0.100195     0.056126  2.768969  0.076493
# 17451    -0.100195     0.447940  2.466584 -0.269113
#
#        transaction_unix_timestamp  disclosure_unix_timestamp  owner_--  \
# 3596                    -1.414277                  -1.450316         0
# 11131                   -1.171259                   0.310047         0
# 14818                   -1.151246                  -1.327856         0
# 11132                   -1.096924                  -1.220703         0
# 11138                   -1.068333                  -1.220703         0
# ...                           ...                        ...       ...
# 13927                    1.113116                   1.102975         0
# 13872                    1.167438                   1.096852         0
# 16168                    1.324685                   1.252988         0
# 16169                    1.373289                   1.390756         0
# 17451                    1.393302                   1.360141         0
#
#        owner_dependent  owner_joint  owner_self  ...  name_Van Taylor  \
# 3596                 0            1           0  ...                0
# 11131                0            1           0  ...                0
# 14818                0            0           1  ...                0
# 11132                0            1           0  ...                0
# 11138                0            1           0  ...                0
# ...                ...          ...         ...  ...              ...
# 13927                0            0           1  ...                0
# 13872                0            0           1  ...                0
# 16168                0            1           0  ...                0
# 16169                0            0           1  ...                0
# 17451                0            1           0  ...                0
#
#        name_Vern Buchanan  name_Vicente Gonzalez  name_Victoria Spartz  \
# 3596                    0                      0                     0
# 11131                   0                      0                     0
# 14818                   0                      0                     0
# 11132                   0                      0                     0
# 11138                   0                      0                     0
# ...                   ...                    ...                   ...
# 13927                   0                      0                     0
# 13872                   0                      0                     0
# 16168                   0                      0                     0
# 16169                   0                      0                     0
# 17451                   0                      0                     0
#
#        name_Virginia Foxx  name_W. Gregory Steube  name_William R. Keating  \
# 3596                    0                       0                        0
# 11131                   0                       0                        0
# 14818                   0                       0                        0
# 11132                   0                       0                        0
# 11138                   0                       0                        0
# ...                   ...                     ...                      ...
# 13927                   0                       0                        0
# 13872                   0                       0                        0
# 16168                   0                       0                        0
# 16169                   0                       0                        0
# 17451                   0                       0                        0
#
#        name_William R. Timmons  name_Wm. Lacy Clay  name_Zoe Lofgren
# 3596                         0                   0                 0
# 11131                        0                   0                 0
# 14818                        0                   0                 0
# 11132                        0                   0                 0
# 11138                        0                   0                 0
# ...                        ...                 ...               ...
# 13927                        0                   0                 0
# 13872                        0                   0                 0
# 16168                        0                   0                 0
# 16169                        0                   0                 0
# 17451                        0                   0                 0
#
# [1232 rows x 376 columns]

# %%
#merge the one-hot encoded df with the original df (result_df pre dummified) based on their indices
anomalous_df = result_df.iloc[anomalous_indices].merge(data_dummies.iloc[anomalous_indices], left_index=True, right_index=True)

anom_names = anomalous_df['name'].unique() #get names out of anomalous df LOOK INTO THEM

# %%
anom_names
# Out:
# array(['Kevin Hern', 'Donald S. Beyer, Jr.', 'Doug Lamborn',
#        'Kurt Schrader', 'Cynthia Axne', 'Virginia Foxx', 'Marie Newman',
#        'Scott H. Peters', 'Blake Moore', 'Marjorie Taylor Greene',
#        'Lois Frankel', 'Harold Dallas Rogers', 'Josh Gottheimer',
#        'Katherine M. Clark', 'James R. Langevin', 'Brian Mast',
#        'Ro Khanna', 'Scott Franklin', 'Susie Lee', 'Peter Meijer',
#        'Dean Phillips', 'Debbie Dingell', 'Carol Devine Miller',
#        'Trey Hollingsworth', 'Ann Wagner', 'Mark E. Green',
#        'Chris Jacobs', 'William R. Keating', 'Michael K. Simpson',
#        'Nancy Pelosi', 'Alan S. Lowenthal', 'Anthony E. Gonzalez',
#        'Elaine Luria', 'August Lee Pfluger', 'James French Hill',
#        'Suzan K. DelBene', 'Mike Garcia', 'Vern Buchanan',
#        'Pete Sessions', 'Charles J. "Chuck" Fleischmann',
#        'Andrew Garbarino', 'Deborah K. Ross', 'Tom Malinowski',
#        'Kathy Manning', 'Richard W. Allen', 'Bob Gibbs',
#        'Victoria Spartz', 'Kathy Castor', 'Dwight Evans',
#        'Patrick Fallon', 'Billy Long'], dtype=object)

# %%
#visualizing the clusters
plt.scatter(data_dummies.iloc[:, 0], data_dummies.iloc[:, 1], c=cluster_labels, cmap='green', s=50, alpha=0.5)
plt.scatter(data_dummies.iloc[anomalous_indices, 0], data_dummies.iloc[anomalous_indices, 1], c='red', s=100, label='Anomalous')
# Out:
#   Cell In[88], line 2
#     plt.scatter(data_dummies.iloc[:, 0], data_dummies.iloc[:, 1], c=cluster_labels, c='green', s=50, alpha=0.5)
#                                                                                     ^
# SyntaxError: keyword argument repeated: c

# %%
# using DBSCAN instead

from sklearn.cluster import DBSCAN
from sklearn.model_selection import ParameterGrid

# Define a grid of parameter values to search over
param_grid = {
    'eps': [0.1, 0.5, 1.0, 2.0, 3.0],
    'min_samples': [3, 5, 10, 50, 100]
}

best_score = -1
best_params = None

# Perform grid search
for params in ParameterGrid(param_grid):
    dbscan = DBSCAN(**params)
    cluster_labels = dbscan.fit_predict(data_dummies)
    silhouette_avg = silhouette_score(data_dummies, cluster_labels)
    
    if silhouette_avg > best_score:
        best_score = silhouette_avg
        best_params = params

print("Best silhouette score:", best_score)
print("Best parameters:", best_params)
# Out:
# Best silhouette score: 0.6214457835604924
# Best parameters: {'eps': 3.0, 'min_samples': 50}

# %%
dbscan = DBSCAN(eps=3.0, min_samples=50)
cluster_labels = dbscan.fit_predict(data_dummies)
n_clusters = len(set(cluster_labels)) - (1 if -1 in cluster_labels else 0)
anomalous_indices2 = np.where(cluster_labels == -1)[0]

# %%
n_clusters
# Out:
# 1

# %%
anomalous_df2 = result_df.iloc[anomalous_indices2].merge(data_dummies.iloc[anomalous_indices2], left_index=True, right_index=True)

anom_names2 = anomalous_df2['name'].unique()

# %%
anomalous_df2
# Out:
#        owner ticker                                  asset_description  \
# 14893   self     MU  Miron Technology Inc - Sold 100 call options p...
# 17487  joint     --  United States Treasury Bills Zero CPN 0.00% Du...
#
#             type                   amount     party state        industry  \
# 14893  sale_full        $15,001 - $50,000  Democrat    CA  Semiconductors
# 17487   purchase  $1,000,001 - $5,000,000  Democrat    WA              na
#
#            sector                                           ptr_link  ...  \
# 14893  Technology  https://disclosures-clerk.house.gov/public_dis...  ...
# 17487     unknown  https://disclosures-clerk.house.gov/public_dis...  ...
#
#       name_Van Taylor  name_Vern Buchanan  name_Vicente Gonzalez  \
# 14893               0                   0                      0
# 17487               0                   0                      0
#
#        name_Victoria Spartz  name_Virginia Foxx  name_W. Gregory Steube  \
# 14893                     0                   0                       0
# 17487                     0                   0                       0
#
#        name_William R. Keating  name_William R. Timmons  name_Wm. Lacy Clay  \
# 14893                        0                        0                   0
# 17487                        0                        0                   0
#
#        name_Zoe Lofgren
# 14893                 0
# 17487                 0
#
# [2 rows x 394 columns]

# %% [markdown]
# ### Autoencoders
# first using autoencoders -- are often used in unsupervised anomaly detection settings where labeled data for training and testing are not available

# %%
import tensorflow as tf
from tensorflow import random as tf_random
from tensorflow import keras
from tensorflow.keras import layers

np.random.seed(123)# random seeds for reproducibility
tf_random.set_seed(123)

#encoder
encoder = keras.Sequential([
    layers.Dense(32, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(6, activation="relu")  #bottleneck
])

#decoder
decoder = keras.Sequential([
    layers.Dense(16, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(376, activation='sigmoid')  #match the number of features in the input data
])

autoencoder = keras.Sequential([encoder, decoder])#combine encoder and decoder into the autoencoder

#compile model
autoencoder.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mse']
)

#training
history = autoencoder.fit(
    data_dummies.values, data_dummies.values,  # Input and target are the same for reconstruction
    epochs=50,
    batch_size=32,
    verbose=0
)

# %%
# Increase Model Capacity
encoder = keras.Sequential([
    layers.Dense(64, activation="relu"),  # Increase units
    layers.Dense(32, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(8, activation="relu")  # Increase bottleneck size
])

decoder = keras.Sequential([
    layers.Dense(16, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(64, activation='relu'),  # Match encoder units
    layers.Dense(377, activation='sigmoid')
])

# Adjust Activation Functions (e.g., Leaky ReLU)
layers.Dense(32, activation=tf.keras.layers.LeakyReLU(alpha=0.1))

# Train Longer
history = autoencoder.fit(
    data_dummies.values, data_dummies.values,
    epochs=100,  # Increase number of epochs
    batch_size=32
    #verbose=1
)

# %%
#reconstruct the data
reconstructed_data = autoencoder.predict(data_dummies.values)

#reconstruction error
reconstruction_errors = np.mean(np.square(data_dummies.values - reconstructed_data))

reconstruction_errors
# Out:
# 584/584 ━━━━━━━━━━━━━━━━━━━━ 1s 875us/step
# 0.013909919474843756

# %% [markdown]
# a MSE of 0.0166 suggests that, on average, the reconstruction error is relatively low, indicating that the autoencoder is performing well in reconstructing the input data

# %%
indices_to_visualize = np.random.randint(0, len(data_dummies), size=5)

for i in indices_to_visualize:
    original_data = data_dummies.iloc[i]
    reconstructed_data_point = reconstructed_data[i]
    
    original_data = original_data.values.reshape((-1,))
    reconstructed_data_point = reconstructed_data_point.reshape((-1,))
    
    plt.figure(figsize=(10, 5))
    
    plt.subplot(1, 2, 1)
    plt.title("Original Data")
    plt.plot(original_data, color='blue')
    
    plt.subplot(1, 2, 2)
    plt.title("Reconstructed Data")
    plt.plot(reconstructed_data_point, color='red')
    
    plt.show()

# %%
threshold = np.percentile(reconstruction_errors, 1)

#mean_error = np.mean(reconstruction_errors)
#std_error = np.std(reconstruction_errors)
#threshold = mean_error + 0.1 * std_error 
row_errors = np.mean(np.square(data_dummies.values - reconstructed_data), axis=1)
anomalous_indices3 = np.where(row_errors > threshold)[0]
anomalous_df3 = data_dummies.iloc[anomalous_indices3]
anomalous_df3
# Out:
#        upper_bound  SP500_Close    Volume       net  \
# 17534    -0.100195    -1.956683 -1.020315  0.068212
# 17535    -0.100195    -1.673168 -1.208407  0.069868
# 17536    -0.052942    -1.545617 -1.183407  0.075389
# 17537    -0.100195    -1.642107 -0.833575  0.077045
# 17538    -0.100195    -1.602628 -0.836905  0.075389
# ...            ...          ...       ...       ...
# 5572      0.217072     0.871560 -1.156845 -0.213352
# 5575      0.217072     0.871560 -1.156845 -0.296165
# 17990    -0.100195     0.744009 -0.458313  0.144952
# 17991    -0.100195     0.744009 -0.458313  0.146608
# 15190     0.217072     1.842016 -1.364183  0.173661
#
#        transaction_unix_timestamp  disclosure_unix_timestamp  owner_--  \
# 17534                   -3.618599                   0.971330         0
# 17535                   -3.355567                   0.971330         0
# 17536                   -2.978174                   0.971330         0
# 17537                   -2.941006                   0.971330         0
# 17538                   -2.918134                   0.971330         0
# ...                           ...                        ...       ...
# 5572                     2.282464                   2.293898         0
# 5575                     2.282464                   2.293898         0
# 17990                    2.288182                   2.296960         0
# 17991                    2.288182                   2.296960         0
# 15190                    2.954339                   1.905088         0
#
#        owner_dependent  owner_joint  owner_self  ...  name_Van Taylor  \
# 17534                0            0           1  ...                0
# 17535                0            0           1  ...                0
# 17536                0            0           1  ...                0
# 17537                0            0           1  ...                0
# 17538                0            0           1  ...                0
# ...                ...          ...         ...  ...              ...
# 5572                 0            0           1  ...                0
# 5575                 0            0           1  ...                0
# 17990                1            0           0  ...                0
# 17991                1            0           0  ...                0
# 15190                0            0           1  ...                0
#
#        name_Vern Buchanan  name_Vicente Gonzalez  name_Victoria Spartz  \
# 17534                   0                      0                     0
# 17535                   0                      0                     0
# 17536                   0                      0                     0
# 17537                   0                      0                     0
# 17538                   0                      0                     0
# ...                   ...                    ...                   ...
# 5572                    0                      0                     0
# 5575                    0                      0                     0
# 17990                   0                      0                     1
# 17991                   0                      0                     1
# 15190                   0                      0                     0
#
#        name_Virginia Foxx  name_W. Gregory Steube  name_William R. Keating  \
# 17534                   0                       0                        0
# 17535                   0                       0                        0
# 17536                   0                       0                        0
# 17537                   0                       0                        0
# 17538                   0                       0                        0
# ...                   ...                     ...                      ...
# 5572                    0                       0                        0
# 5575                    0                       0                        0
# 17990                   0                       0                        0
# 17991                   0                       0                        0
# 15190                   0                       0                        0
#
#        name_William R. Timmons  name_Wm. Lacy Clay  name_Zoe Lofgren
# 17534                        0                   0                 0
# 17535                        0                   0                 0
# 17536                        0                   0                 0
# 17537                        0                   0                 0
# 17538                        0                   0                 0
# ...                        ...                 ...               ...
# 5572                         0                   0                 0
# 5575                         0                   0                 0
# 17990                        0                   0                 0
# 17991                        0                   0                 0
# 15190                        0                   0                 0
#
# [4921 rows x 376 columns]

# %%
anomalous_df3 = result_df.iloc[anomalous_indices3].merge(data_dummies.iloc[anomalous_indices3], left_index=True, right_index=True)
anom_names3 = anomalous_df3['name'].unique()

# %%
common_elements = np.intersect1d(anom_names3, anom_names)
print(f'names to investigate: \n { common_elements}')
#len(np.intersect1d(anom_names2, anom_names3))
#len(np.setdiff1d(anom_names2, anom_names3))
# Out:
# names to investigate:
#  ['Alan S. Lowenthal' 'Ann Wagner' 'Billy Long' 'Bob Gibbs' 'Brian Mast'
#  'Carol Devine Miller' 'Cynthia Axne' 'Dean Phillips' 'Debbie Dingell'
#  'Donald S. Beyer, Jr.' 'Dwight Evans' 'James French Hill'
#  'James R. Langevin' 'Josh Gottheimer' 'Katherine M. Clark' 'Kathy Castor'
#  'Kathy Manning' 'Kevin Hern' 'Kurt Schrader' 'Lois Frankel'
#  'Mark E. Green' 'Michael K. Simpson' 'Mike Garcia' 'Nancy Pelosi'
#  'Richard W. Allen' 'Scott Franklin' 'Scott H. Peters' 'Susie Lee'
#  'Suzan K. DelBene' 'Tom Malinowski' 'Vern Buchanan' 'Virginia Foxx']

# %%
result_df.columns
# Out:
# Index(['owner', 'ticker', 'asset_description', 'type', 'amount', 'party',
#        'state', 'industry', 'sector', 'ptr_link', 'name', 'year',
#        'upper_bound', 'SP500_Close', 'Volume', 'net',
#        'transaction_unix_timestamp', 'disclosure_unix_timestamp'],
#       dtype='object')

# %%
anomaly_result2 = result_df[result_df['name'].isin(common_elements) & (result_df['ticker'] != '--')][['name', 'party','ticker', 'amount', 'state', 'industry', 'sector', 'upper_bound', 'SP500_Close', 'Volume']].drop_duplicates(subset='name')

anomaly_result2
# Out:
#                        name       party ticker                   amount state  \
# 17668        Tom Malinowski    Democrat  BLFSD         $1,001 - $15,000    NJ
# 1638    Carol Devine Miller  Republican   MZOR        $15,001 - $50,000    WV
# 2211           Cynthia Axne    Democrat     FB         $1,001 - $15,000    IA
# 7284      James R. Langevin    Democrat   BABA       $50,001 - $100,000    RI
# 38        Alan S. Lowenthal    Democrat     LB        $15,001 - $50,000    CA
# 3596   Donald S. Beyer, Jr.    Democrat  TDDXX  $1,000,001 - $5,000,000    VA
# 8368        Josh Gottheimer    Democrat   TSLA         $1,001 - $15,000    NJ
# 2898          Dean Phillips    Democrat    ETN         $1,001 - $15,000    MN
# 11127            Kevin Hern  Republican    FSK      $100,001 - $250,000    OK
# 17992         Virginia Foxx  Republican     SO         $1,001 - $15,000    NC
# 12297          Lois Frankel    Democrat   STOR         $1,001 - $15,000    FL
# 7271      James French Hill  Republican   AAWW        $15,001 - $50,000    AR
# 15551      Richard W. Allen  Republican    UTX         $1,001 - $15,000    GA
# 10706          Kathy Castor    Democrat    BIF         $1,001 - $15,000    FL
# 17298      Suzan K. DelBene    Democrat   MSFT         $1,001 - $15,000    WA
# 3419         Debbie Dingell    Democrat    NEE       $50,001 - $100,000    MI
# 1489              Bob Gibbs  Republican   AAPL        $15,001 - $50,000    OH
# 16596             Susie Lee    Democrat     RP         $1,001 - $15,000    NV
# 11780         Kurt Schrader    Democrat    BLK         $1,001 - $15,000    OR
# 1573             Brian Mast  Republican     AM        $15,001 - $50,000    FL
# 14815          Nancy Pelosi    Democrat   AMZN      $250,001 - $500,000    CA
# 10280    Katherine M. Clark    Democrat    UPS        $15,001 - $50,000    MA
# 5217           Dwight Evans    Democrat    TMO         $1,001 - $15,000    PA
# 1268             Billy Long  Republican     SO        $15,001 - $50,000    MO
# 13978    Michael K. Simpson  Republican    PSX         $1,001 - $15,000    ID
# 14514           Mike Garcia  Republican   TSLA         $1,001 - $15,000    CA
# 13260         Mark E. Green  Republican   AMZA      $250,001 - $500,000    TN
# 16343       Scott H. Peters    Democrat   RAND         $1,001 - $15,000    CA
# 10754         Kathy Manning    Democrat   INTL         $1,001 - $15,000    NC
# 16246        Scott Franklin  Republican    BRP  $1,000,001 - $5,000,000    FL
# 996              Ann Wagner  Republican    SYF      $100,001 - $250,000    MO
#
#                                               industry  \
# 17668                                               na
# 1638                                                na
# 2211   Computer Software: Programming, Data Processing
# 7284                                 Business Services
# 38                      Clothing/Shoe/Accessory Stores
# 3596                                                na
# 8368                                Auto Manufacturing
# 2898                   Industrial Machinery/Components
# 11127                                               na
# 17992                      Electric Utilities: Central
# 12297                    Real Estate Investment Trusts
# 7271                           Transportation Services
# 15551                                               na
# 10706                                               na
# 17298          Computer Software: Prepackaged Software
# 3419                       Electric Utilities: Central
# 1489                            Computer Manufacturing
# 16596          Computer Software: Prepackaged Software
# 11780               Investment Bankers/Brokers/Service
# 1573                          Natural Gas Distribution
# 14815                   Catalog/Specialty Distribution
# 10280                Trucking Freight/Courier Services
# 5217                   Industrial Machinery/Components
# 1268                       Electric Utilities: Central
# 13978                         Integrated oil Companies
# 14514                               Auto Manufacturing
# 13260                                               na
# 16343                       Finance/Investors Services
# 10754                                               na
# 16246                               Specialty Insurers
# 996                         Finance: Consumer Services
#
#                        sector  upper_bound  SP500_Close    Volume
# 17668                 unknown    -0.100195          NaN       NaN
# 1638                  unknown    -0.052942    -1.905445 -0.539481
# 2211               Technology    -0.100195    -1.604629 -0.637638
# 7284            Miscellaneous     0.014561    -1.244901 -1.329858
# 38          Consumer Services    -0.052942    -1.135791 -0.687434
# 3596                  unknown     6.629919    -1.077060 -1.225592
# 8368            Capital Goods    -0.100195    -0.916100 -1.368449
# 2898               Technology    -0.100195    -0.871676 -1.183740
# 11127                 unknown     0.217072    -0.873512 -0.868708
# 17992        Public Utilities    -0.100195    -0.835141 -1.097120
# 12297             Real Estate    -0.100195    -0.743365 -0.591436
# 7271   Consumer Discretionary    -0.052942    -0.720342 -0.807261
# 15551                 unknown    -0.100195    -0.663033 -1.830520
# 10706                 unknown    -0.100195    -0.663033 -1.830520
# 17298              Technology    -0.100195    -0.678316 -1.478959
# 3419         Public Utilities     0.014561    -0.633544 -1.052224
# 1489               Technology    -0.052942    -0.633544 -1.052224
# 16596              Technology    -0.100195    -0.652680 -0.869100
# 11780                 Finance    -0.100195    -0.667731 -1.070361
# 1573         Public Utilities    -0.052942    -0.641483 -0.850692
# 14815       Consumer Services     0.554591    -0.536029 -0.991329
# 10280          Transportation    -0.052942    -0.590856 -0.802739
# 5217            Capital Goods    -0.100195    -0.910775  1.153595
# 1268         Public Utilities    -0.052942    -2.075303  2.228885
# 13978                  Energy    -0.100195    -1.927392  2.602305
# 14514           Capital Goods    -0.100195    -1.145169  0.092961
# 13260                 unknown     0.554591    -1.073620  0.751279
# 16343                 Finance    -0.100195    -0.698725 -0.604287
# 10754                 unknown    -0.100195     0.210619  0.389849
# 16246                 Finance     6.629919     0.455614 -0.198234
# 996                   Finance     0.217072     0.509102  0.104272

# %%
#making a new dataframe based on the marked anomalous names and indices
anomaly_result = result_df[result_df['name'].isin(common_elements)][['name', 'party','ticker', 'amount', 'state', 'industry', 'sector', 'net', 'SP500_Close', 'Volume', 'transaction_unix_timestamp', 'disclosure_unix_timestamp']].drop_duplicates(subset='name')

#convert unix timestamp back to datetime 
anomaly_result['transaction_datetime'] = pd.to_datetime(anomaly_result['transaction_unix_timestamp'], unit='s',  origin='unix', utc=True).dt.date
anomaly_result['disclosure_datetime'] = pd.to_datetime(anomaly_result['disclosure_unix_timestamp'], unit='s',  origin='unix', utc=True).dt.date
anomaly_result.drop(['transaction_unix_timestamp', 'disclosure_unix_timestamp'], axis=1, inplace=True)

anomaly_result
# Out:
#                        name       party ticker                   amount state  \
# 17668        Tom Malinowski    Democrat  BLFSD         $1,001 - $15,000    NJ
# 1638    Carol Devine Miller  Republican   MZOR        $15,001 - $50,000    WV
# 2211           Cynthia Axne    Democrat     FB         $1,001 - $15,000    IA
# 7284      James R. Langevin    Democrat   BABA       $50,001 - $100,000    RI
# 37        Alan S. Lowenthal    Democrat     --        $15,001 - $50,000    CA
# 10279    Katherine M. Clark    Democrat     --         $1,001 - $15,000    MA
# 3596   Donald S. Beyer, Jr.    Democrat  TDDXX  $1,000,001 - $5,000,000    VA
# 8368        Josh Gottheimer    Democrat   TSLA         $1,001 - $15,000    NJ
# 2903          Dean Phillips    Democrat     --        $15,001 - $50,000    MN
# 11123            Kevin Hern  Republican     --         $1,001 - $15,000    OK
# 17992         Virginia Foxx  Republican     SO         $1,001 - $15,000    NC
# 17296      Suzan K. DelBene    Democrat     --      $250,001 - $500,000    WA
# 12297          Lois Frankel    Democrat   STOR         $1,001 - $15,000    FL
# 7271      James French Hill  Republican   AAWW        $15,001 - $50,000    AR
# 15551      Richard W. Allen  Republican    UTX         $1,001 - $15,000    GA
# 10706          Kathy Castor    Democrat    BIF         $1,001 - $15,000    FL
# 3419         Debbie Dingell    Democrat    NEE       $50,001 - $100,000    MI
# 1489              Bob Gibbs  Republican   AAPL        $15,001 - $50,000    OH
# 16596             Susie Lee    Democrat     RP         $1,001 - $15,000    NV
# 17919         Vern Buchanan  Republican     --      $100,001 - $250,000    FL
# 11780         Kurt Schrader    Democrat    BLK         $1,001 - $15,000    OR
# 1573             Brian Mast  Republican     AM        $15,001 - $50,000    FL
# 14815          Nancy Pelosi    Democrat   AMZN      $250,001 - $500,000    CA
# 16310       Scott H. Peters    Democrat     --    $500,001 - $1,000,000    CA
# 974              Ann Wagner  Republican     --       $50,001 - $100,000    MO
# 5217           Dwight Evans    Democrat    TMO         $1,001 - $15,000    PA
# 1268             Billy Long  Republican     SO        $15,001 - $50,000    MO
# 13978    Michael K. Simpson  Republican    PSX         $1,001 - $15,000    ID
# 14514           Mike Garcia  Republican   TSLA         $1,001 - $15,000    CA
# 13260         Mark E. Green  Republican   AMZA      $250,001 - $500,000    TN
# 10754         Kathy Manning    Democrat   INTL         $1,001 - $15,000    NC
# 16246        Scott Franklin  Republican    BRP  $1,000,001 - $5,000,000    FL
#
#                                               industry  \
# 17668                                               na
# 1638                                                na
# 2211   Computer Software: Programming, Data Processing
# 7284                                 Business Services
# 37                                                  na
# 10279                                               na
# 3596                                                na
# 8368                                Auto Manufacturing
# 2903                                                na
# 11123                                               na
# 17992                      Electric Utilities: Central
# 17296                                               na
# 12297                    Real Estate Investment Trusts
# 7271                           Transportation Services
# 15551                                               na
# 10706                                               na
# 3419                       Electric Utilities: Central
# 1489                            Computer Manufacturing
# 16596          Computer Software: Prepackaged Software
# 17919                                               na
# 11780               Investment Bankers/Brokers/Service
# 1573                          Natural Gas Distribution
# 14815                   Catalog/Specialty Distribution
# 16310                                               na
# 974                                                 na
# 5217                   Industrial Machinery/Components
# 1268                       Electric Utilities: Central
# 13978                         Integrated oil Companies
# 14514                               Auto Manufacturing
# 13260                                               na
# 10754                                               na
# 16246                               Specialty Insurers
#
#                        sector       net  SP500_Close    Volume  \
# 17668                 unknown  0.068212          NaN       NaN
# 1638                  unknown  0.061035    -1.905445 -0.539481
# 2211               Technology  0.068212    -1.604629 -0.637638
# 7284            Miscellaneous  0.055514    -1.244901 -1.329858
# 37                    unknown  0.072077    -1.470082 -0.657526
# 10279                 unknown  0.064900    -1.119004 -1.003198
# 3596                  unknown  0.618643    -1.077060 -1.225592
# 8368            Capital Goods  0.064900    -0.916100 -1.368449
# 2903                  unknown  0.062691    -0.871676 -1.183740
# 11123                 unknown  0.068212    -0.905863 -0.892417
# 17992        Public Utilities  0.068212    -0.835141 -1.097120
# 17296                 unknown  0.011347    -0.743365 -0.591436
# 12297             Real Estate  0.064900    -0.743365 -0.591436
# 7271   Consumer Discretionary  0.072077    -0.720342 -0.807261
# 15551                 unknown  0.059379    -0.663033 -1.830520
# 10706                 unknown  0.068212    -0.663033 -1.830520
# 3419         Public Utilities  0.055514    -0.633544 -1.052224
# 1489               Technology  0.072077    -0.633544 -1.052224
# 16596              Technology  0.071525    -0.652680 -0.869100
# 17919                 unknown -0.099070    -0.667731 -1.070361
# 11780                 Finance  0.064900    -0.667731 -1.070361
# 1573         Public Utilities  0.061035    -0.641483 -0.850692
# 14815       Consumer Services  0.066556    -0.536029 -0.991329
# 16310                 unknown -0.209488    -0.657063 -0.772008
# 974                   unknown  0.077598    -0.442714 -0.629959
# 5217            Capital Goods  0.069868    -0.910775  1.153595
# 1268         Public Utilities -0.789179    -2.075303  2.228885
# 13978                  Energy  0.071525    -1.927392  2.602305
# 14514           Capital Goods  0.064900    -1.145169  0.092961
# 13260                 unknown  0.011347    -1.073620  0.751279
# 10754                 unknown  0.071525     0.210619  0.389849
# 16246                 Finance -0.485531     0.455614 -0.198234
#
#       transaction_datetime disclosure_datetime
# 17668           1969-12-31          1970-01-01
# 1638            1969-12-31          1969-12-31
# 2211            1969-12-31          1970-01-01
# 7284            1969-12-31          1969-12-31
# 37              1969-12-31          1970-01-01
# 10279           1969-12-31          1969-12-31
# 3596            1969-12-31          1969-12-31
# 8368            1969-12-31          1969-12-31
# 2903            1969-12-31          1969-12-31
# 11123           1969-12-31          1969-12-31
# 17992           1969-12-31          1969-12-31
# 17296           1969-12-31          1969-12-31
# 12297           1969-12-31          1969-12-31
# 7271            1969-12-31          1969-12-31
# 15551           1969-12-31          1970-01-01
# 10706           1969-12-31          1969-12-31
# 3419            1969-12-31          1969-12-31
# 1489            1969-12-31          1969-12-31
# 16596           1969-12-31          1969-12-31
# 17919           1969-12-31          1969-12-31
# 11780           1969-12-31          1969-12-31
# 1573            1969-12-31          1969-12-31
# 14815           1969-12-31          1969-12-31
# 16310           1969-12-31          1969-12-31
# 974             1969-12-31          1969-12-31
# 5217            1969-12-31          1969-12-31
# 1268            1969-12-31          1969-12-31
# 13978           1969-12-31          1969-12-31
# 14514           1969-12-31          1969-12-31
# 13260           1969-12-31          1969-12-31
# 10754           1969-12-31          1969-12-31
# 16246           1969-12-31          1969-12-31

# %%
#next steps...

#extract the encoder part from the trained autoencoder model
#encoded representation w/ reduced dimensions compared to the original input data


#compare the names from both models, improve autoencoder, maybe try forest
#make visuals for cluster
#start searching up names from the webpage, maybe extract into a csv

#insights - democrats or republicans more sus

# %% [markdown]
# ### Isolation forest

# %%
from sklearn.ensemble import IsolationForest

data_dummies.dropna(inplace=True)

#train and fit
isolation_forest = IsolationForest(n_estimators=100, max_samples='auto', contamination='auto', random_state=42)
isolation_forest.fit(data_dummies)

predictions = isolation_forest.predict(data_dummies)

anomaly_scores = isolation_forest.decision_function(data_dummies)

np.where(predictions == -1)[0]

# %%
#next steps:  precision, recall, F1-score, ROC curve analysis,
